# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("./test images/Trump-Test1.jpg")
img.shape
# Out:
# (224, 225, 3)

# %%
plt.imshow(img)
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (224, 225)

# %%
gray
# Out:
# array([[244, 242, 238, ..., 221, 220, 223],
#        [244, 242, 238, ..., 221, 220, 223],
#        [245, 242, 239, ..., 221, 220, 223],
#        ...,
#        [244, 217,   1, ..., 210, 210, 229],
#        [244, 217,   1, ..., 210, 210, 229],
#        [244, 217,   1, ..., 210, 210, 229]], dtype=uint8)

# %%
plt.imshow(gray, cmap = "gray")
plt.show()
